# %% [markdown]
# ## Fine-tuning Stable Diffusion XL with DreamBooth and LoRA on a free-tier Colab Notebook
#
# In this notebook, we show how to fine-tune [Stable Diffusion XL (SDXL)](https://huggingface.co/docs/diffusers/main/en/api/pipelines/stable_diffusion/stable_diffusion_xl) with [DreamBooth](https://huggingface.co/docs/diffusers/main/en/training/dreambooth) and [LoRA](https://huggingface.co/docs/diffusers/main/en/training/lora) on a T4 GPU.
#
# SDXL consists of a much larger UNet and two text encoders that make the cross-attention context quite larger than the previous variants.
#
# So, to pull this off, we will make use of several tricks such as gradient checkpointing, mixed-precision, and 8-bit Adam. So, hang tight and let's get started.

# %% [markdown]
# ## Setup

# %%
# Check the GPU
# !nvidia-smi
# Out:
# Wed Dec 18 00:32:45 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   57C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
# Install dependencies.
# !pip install bitsandbytes transformers accelerate peft -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.1/69.1 MB 8.7 MB/s eta 0:00:00

# %% [markdown]
# Make sure to install `diffusers` from `main`.

# %%
# !pip install git+https://github.com/huggingface/diffusers.git -q
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for diffusers (pyproject.toml) ... done

# %% [markdown]
# Download diffusers SDXL DreamBooth training script.

# %%
# !wget https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Out:
# --2024-12-18 00:33:54--  https://raw.githubusercontent.com/huggingface/diffusers/main/examples/dreambooth/train_dreambooth_lora_sdxl.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84922 (83K) [text/plain]
# Saving to: ‘train_dreambooth_lora_sdxl.py’
#
# train_dreambooth_lo 100%[===================>]  82.93K  --.-KB/s    in 0.02s
#
# 2024-12-18 00:33:55 (5.19 MB/s) - ‘train_dreambooth_lora_sdxl.py’ saved [84922/84922]

# %% [markdown]
# ## Dataset

# %% [markdown]
# **Let's get our training data!**
# For this project, we have images of a friend who volenteered to give his photos to us.

# %% [markdown]
# **Option 1:** upload example images from your local files:

# %%
import os
import shutil

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Source path to the 'pitt' folder in Google Drive
source_path = "/content/drive/My Drive/dl_project"  # Path to the 'pitt' folder in Google Drive

# Define the destination directory in Colab
destination_dir = "/content/dl_project_images/"
os.makedirs(destination_dir, exist_ok=True)  # Create the directory if it doesn't exist

# Copy the 'pitt' folder from Google Drive to the local directory
shutil.copytree(source_path, destination_dir, dirs_exist_ok=True)  # Copy folder content
print(f"Copied 'dl_project' folder to {destination_dir}")

# Verify the copied files
print(f"Copied files to {destination_dir}")
print("Extracted images:")
print(os.listdir(destination_dir))
# Out:
# Mounted at /content/drive
# Copied 'dl_project' folder to /content/dl_project_images/
# Copied files to /content/dl_project_images/
# Extracted images:
# ['IMG_6586.jpg', 'IMG_2360.jpg', 'agog.jpg', 'IMG_2359.jpg', 'IMG_6585.jpg']

# %% [markdown]
# Preview the images:

# %%
from PIL import Image

def image_grid(imgs, rows, cols, resize=256):

    if resize is not None:
        imgs = [img.resize((resize, resize)) for img in imgs]
    w, h = imgs[0].size
    grid = Image.new("RGB", size=(cols * w, rows * h))
    grid_w, grid_h = grid.size

    for i, img in enumerate(imgs):
        grid.paste(img, box=(i % cols * w, i // cols * h))
    return grid

# %%
import glob

# change path to display images from your local dir
img_paths = "./dl_project_images/*.jpg"
imgs = [Image.open(path) for path in glob.glob(img_paths)]

num_imgs_to_preview = 5
image_grid(imgs[:num_imgs_to_preview], 1, num_imgs_to_preview)
# Out:
# <PIL.Image.Image image mode=RGB size=1280x256>

# %% [markdown]
# ### Generate custom captions with BLIP
# Load BLIP to auto caption your images:

# %%
import requests
from transformers import AutoProcessor, BlipForConditionalGeneration
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

# load the processor and the captioning model
blip_processor = AutoProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
blip_model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base",torch_dtype=torch.float16).to(device)

# captioning utility
def caption_images(input_image):
    inputs = blip_processor(images=input_image, return_tensors="pt").to(device, torch.float16)
    pixel_values = inputs.pixel_values

    generated_ids = blip_model.generate(pixel_values=pixel_values, max_length=50)
    generated_caption = blip_processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    return generated_caption
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/287 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/506 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/711k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/990M [00:00<?, ?B/s]

# %%
import glob
from PIL import Image

# create a list of (Pil.Image, path) pairs
local_dir = "./dl_project_images/"
imgs_and_paths = [(path,Image.open(path)) for path in glob.glob(f"{local_dir}*.jpg")]

# %% [markdown]
# Now let's add the concept token identifier (e.g. TOK) to each caption using a caption prefix.
# - for example we can use "a photo of TOK," other options include:
#     - For styles - "In the style of TOK"
#     - For faces - "photo of a TOK person"
# - For this project we will use the full name instead of TOK.

# %%
import os
import json

# Define paths
local_dir = "/content/dl_project_images/"
metadata_dir = "/content/dl_project_metadata/"  # New directory for metadata
os.makedirs(metadata_dir, exist_ok=True)

caption_prefix = "A photo of Advik Gupta wearing casual clothes, taking a selfie, and smiling."  # Define caption prefix

# Create metadata.jsonl
metadata_path = os.path.join(metadata_dir, "metadata.jsonl")
with open(metadata_path, 'w') as outfile:
    for img in imgs_and_paths:  # Ensure imgs_and_paths is properly defined
        caption = caption_prefix + caption_images(img[1]).split("\n")[0]
        entry = {"file_name": img[0].split("/")[-1], "prompt": caption}
        json.dump(entry, outfile)
        outfile.write('\n')

print(f"Metadata saved to {metadata_path}")
# Out:
# model.safetensors:   0%|          | 0.00/990M [00:00<?, ?B/s]
# Metadata saved to /content/dl_project_metadata/metadata.jsonl

# %% [markdown]
# Free some memory:

# %%
import gc

# delete the BLIP pipelines and free up some memory
del blip_processor, blip_model
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ## Prep for training

# %% [markdown]
# Initialize `accelerate`:

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# !accelerate config default
# Out:
# accelerate configuration saved at /root/.cache/huggingface/accelerate/default_config.yaml

# %% [markdown]
# ### Log into your Hugging Face account
# Pass [your **write** access token](https://huggingface.co/settings/tokens) so that we can push the trained checkpoints to the Hugging Face Hub:

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Train!

# %% [markdown]
# #### Set Hyperparameters
# To ensure we can DreamBooth with LoRA on a heavy pipeline like Stable Diffusion XL, we're using:
#
# * Gradient checkpointing (`--gradient_accumulation_steps`)
# * 8-bit Adam (`--use_8bit_adam`)
# * Mixed-precision training (`--mixed-precision="fp16"`)

# %% [markdown]
# ### Launching training

# %% [markdown]
# To allow for custom captions we need to install the `datasets` library, you can skip that if you want to train solely
#  with `--instance_prompt`.
# In that case, specify `--instance_data_dir` instead of `--dataset_name`

# %%
# !pip install datasets -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.3/179.3 kB 16.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 12.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 17.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2024.9.0 which is incompatible.

# %% [markdown]
#  - Use `--output_dir` to specify your LoRA model repository name!
#  - Use `--caption_column` to specify name of the cpation column in your dataset. In this example we used "prompt" to
#  save our captions in the
#  metadata file, change this according to your needs.

# %%
#!/usr/bin/env bash
# !accelerate launch train_dreambooth_lora_sdxl.py \
  --pretrained_model_name_or_path="stabilityai/stable-diffusion-xl-base-1.0" \
  --pretrained_vae_model_name_or_path="madebyollin/sdxl-vae-fp16-fix" \
  --instance_data_dir="./dl_project_images" \
  --output_dir="dl_project_LoRA" \
  --mixed_precision="fp16" \
  --instance_prompt="A photo of Advik Gupta wearing casual clothes, taking a selfie, and smiling." \
  --resolution=1024 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=3 \
  --gradient_checkpointing \
  --learning_rate=1e-4 \
  --snr_gamma=5.0 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --use_8bit_adam \
  --max_train_steps=500 \
  --checkpointing_steps=717 \
  --seed="0"
# Out:
# 2024-12-18 00:35:40.487013: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-12-18 00:35:40.516706: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-12-18 00:35:40.525824: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-12-18 00:35:42.202218: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 12/18/2024 00:35:45 - INFO - __main__ - Distributed environment: NO
# Num processes: 1
# Process index: 0
# Local process index: 0
# Device: cuda
#
# Mixed precision type: fp16
#
# tokenizer/tokenizer_config.json: 100% 737/737 [00:00<00:00, 5.34MB/s]
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 5.29MB/s]
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 4.00MB/s]
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 2.86MB/s]
# tokenizer_2/tokenizer_config.json: 100% 725/725 [00:00<00:00, 5.22MB/s]
# tokenizer_2/special_tokens_map.json: 100% 460/460 [00:00<00:00, 3.63MB/s]
# text_encoder/config.json: 100% 565/565 [00:00<00:00, 4.45MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# text_encoder_2/config.json: 100% 575/575 [00:00<00:00, 4.09MB/s]
# You are using a model of type clip_text_model to instantiate a model of type . This is not supported for all configurations of models and can yield errors.
# model_index.json: 100% 609/609 [00:00<00:00, 4.79MB/s]
# scheduler/scheduler_config.json: 100% 479/479 [00:00<00:00, 2.95MB/s]
# {'rescale_betas_zero_snr', 'thresholding', 'variance_type', 'clip_sample_range', 'dynamic_thresholding_ratio'} was not found in config. Values will be initialized to default values.
# model.safetensors: 100% 492M/492M [00:02<00:00, 187MB/s]
# model.safetensors: 100% 2.78G/2.78G [00:28<00:00, 96.8MB/s]
# config.json: 100% 631/631 [00:00<00:00, 4.27MB/s]
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:01<00:00, 214MB/s]
# {'latents_mean', 'mid_block_add_attention', 'latents_std', 'use_quant_conv', 'use_post_quant_conv', 'shift_factor'} was not found in config. Values will be initialized to default values.
# unet/config.json: 100% 1.68k/1.68k [00:00<00:00, 13.4MB/s]
# diffusion_pytorch_model.safetensors: 100% 10.3G/10.3G [01:03<00:00, 162MB/s]
# {'reverse_transformer_layers_per_block', 'attention_type', 'dropout'} was not found in config. Values will be initialized to default values.
# 12/18/2024 00:38:33 - INFO - __main__ - ***** Running training *****
# 12/18/2024 00:38:33 - INFO - __main__ -   Num examples = 5
# 12/18/2024 00:38:33 - INFO - __main__ -   Num batches each epoch = 5
# 12/18/2024 00:38:33 - INFO - __main__ -   Num Epochs = 500
# 12/18/2024 00:38:33 - INFO - __main__ -   Instantaneous batch size per device = 1
# 12/18/2024 00:38:33 - INFO - __main__ -   Total train batch size (w. parallel, distributed & accumulation) = 3
# 12/18/2024 00:38:33 - INFO - __main__ -   Gradient Accumulation steps = 3
# 12/18/2024 00:38:33 - INFO - __main__ -   Total optimization steps = 1000
# Steps:  72% 717/1000 [1:31:39<37:28,  7.94s/it, loss=0.0718, lr=0.0001]12/18/2024 02:10:12 - INFO - accelerate.accelerator - Saving current state to dl_project_LoRA/checkpoint-717
# Model weights saved in dl_project_LoRA/checkpoint-717/pytorch_lora_weights.safetensors
# 12/18/2024 02:10:13 - INFO - accelerate.checkpointing - Optimizer state saved in dl_project_LoRA/checkpoint-717/optimizer.bin
# 12/18/2024 02:10:13 - INFO - accelerate.checkpointing - Scheduler state saved in dl_project_LoRA/checkpoint-717/scheduler.bin
# 12/18/2024 02:10:13 - INFO - accelerate.checkpointing - Sampler state for dataloader 0 saved in dl_project_LoRA/checkpoint-717/sampler.bin
# 12/18/2024 02:10:13 - INFO - accelerate.checkpointing - Gradient scaler state saved in dl_project_LoRA/checkpoint-717/scaler.pt
# 12/18/2024 02:10:13 - INFO - accelerate.checkpointing - Random states saved in dl_project_LoRA/checkpoint-717/random_states_0.pkl
# 12/18/2024 02:10:13 - INFO - __main__ - Saved state to dl_project_LoRA/checkpoint-717
# Steps: 100% 1000/1000 [2:07:47<00:00,  7.31s/it, loss=0.0624, lr=0.0001]Model weights saved in dl_project_LoRA/pytorch_lora_weights.safetensors
# {'latents_mean', 'mid_block_add_attention', 'latents_std', 'use_quant_conv', 'use_post_quant_conv', 'shift_factor'} was not found in config. Values will be initialized to default values.
#
# Fetching 17 files:   0% 0/17 [00:00<?, ?it/s]
#
# diffusion_pytorch_model.safetensors:   0% 0.00/335M [00:00<?, ?B/s]
#
# diffusion_pytorch_model.safetensors:   6% 21.0M/335M [00:00<00:02, 136MB/s]
#
# diffusion_pytorch_model.safetensors:  16% 52.4M/335M [00:00<00:01, 192MB/s]
#
# diffusion_pytorch_model.safetensors:  25% 83.9M/335M [00:00<00:01, 201MB/s]
#
# diffusion_pytorch_model.safetensors:  31% 105M/335M [00:00<00:01, 196MB/s]
#
# diffusion_pytorch_model.safetensors:  38% 126M/335M [00:00<00:01, 181MB/s]
#
# diffusion_pytorch_model.safetensors:  44% 147M/335M [00:00<00:01, 182MB/s]
#
# diffusion_pytorch_model.safetensors:  53% 178M/335M [00:00<00:00, 197MB/s]
#
# diffusion_pytorch_model.safetensors:  63% 210M/335M [00:01<00:00, 207MB/s]
#
# diffusion_pytorch_model.safetensors:  69% 231M/335M [00:01<00:00, 193MB/s]
#
# diffusion_pytorch_model.safetensors:  75% 252M/335M [00:01<00:00, 187MB/s]
#
# diffusion_pytorch_model.safetensors:  81% 273M/335M [00:01<00:00, 187MB/s]
#
# diffusion_pytorch_model.safetensors:  88% 294M/335M [00:01<00:00, 188MB/s]
#
# diffusion_pytorch_model.safetensors:  94% 315M/335M [00:01<00:00, 189MB/s]
#
# diffusion_pytorch_model.safetensors: 100% 335M/335M [00:03<00:00, 85.1MB/s]
#
# Fetching 17 files: 100% 17/17 [00:04<00:00,  4.14it/s]
# {'feature_extractor', 'image_encoder'} was not found in config. Values will be initialized to default values.
#
# Loading pipeline components...:   0% 0/7 [00:00<?, ?it/s]Loaded tokenizer as CLIPTokenizer from `tokenizer` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'timestep_type', 'sigma_min', 'rescale_betas_zero_snr', 'use_exponential_sigmas', 'use_beta_sigmas', 'final_sigmas_type', 'sigma_max'} was not found in config. Values will be initialized to default values.
# Loaded scheduler as EulerDiscreteScheduler from `scheduler` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  29% 2/7 [00:00<00:00, 18.86it/s]Loaded text_encoder_2 as CLIPTextModelWithProjection from `text_encoder_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  57% 4/7 [00:04<00:03,  1.23s/it]Loaded tokenizer_2 as CLIPTokenizer from `tokenizer_2` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
# {'reverse_transformer_layers_per_block', 'attention_type', 'dropout'} was not found in config. Values will be initialized to default values.
# Loaded unet as UNet2DConditionModel from `unet` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...:  86% 6/7 [00:59<00:13, 13.39s/it]Loaded text_encoder as CLIPTextModel from `text_encoder` subfolder of stabilityai/stable-diffusion-xl-base-1.0.
#
# Loading pipeline components...: 100% 7/7 [01:03<00:00,  9.01s/it]
# Loading unet.
# Steps: 100% 1000/1000 [2:08:59<00:00,  7.74s/it, loss=0.0624, lr=0.0001]

# %% [markdown]
# ### Saving our model to the hub to check it out

# %%
from huggingface_hub import whoami
from pathlib import Path
output_dir = "dl_project_LoRA"
username = whoami(token=Path("/root/.cache/huggingface/"))["name"]
repo_id = f"{username}/{output_dir}"

# %%
# push to the hub
from train_dreambooth_lora_sdxl import save_model_card
from huggingface_hub import upload_folder, create_repo

repo_id = create_repo(repo_id, exist_ok=True).repo_id

# change the params below according to your training arguments
save_model_card(
    repo_id = repo_id,
    images=[],
    base_model="stabilityai/stable-diffusion-xl-base-1.0",
    train_text_encoder=False,
    instance_prompt="A photo of Advik Gupta wearing casual clothes, taking a selfie, and smiling.",
    validation_prompt=None,
    repo_folder=output_dir,
    vae_path="madebyollin/sdxl-vae-fp16-fix",
    use_dora=False  # Add this argument
)

upload_folder(
    repo_id=repo_id,
    folder_path=output_dir,
    commit_message="End of training",
    ignore_patterns=["step_*", "epoch_*"],
)
# Out:
# README.md:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# optimizer.bin:   0%|          | 0.00/15.1M [00:00<?, ?B/s]
# pytorch_lora_weights.safetensors:   0%|          | 0.00/23.4M [00:00<?, ?B/s]
# random_states_0.pkl:   0%|          | 0.00/14.3k [00:00<?, ?B/s]
# scaler.pt:   0%|          | 0.00/988 [00:00<?, ?B/s]
# Upload 8 LFS files:   0%|          | 0/8 [00:00<?, ?it/s]
# scheduler.bin:   0%|          | 0.00/1.00k [00:00<?, ?B/s]
# events.out.tfevents.1734482313.96257a60bec2.1703.1:   0%|          | 0.00/3.33k [00:00<?, ?B/s]
# events.out.tfevents.1734482313.96257a60bec2.1703.0:   0%|          | 0.00/209k [00:00<?, ?B/s]
# pytorch_lora_weights.safetensors:   0%|          | 0.00/23.4M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/nikhilsoni700/dl_project_LoRA/commit/843c6edcf99e5912143d4c114ea39ce833059052', commit_message='End of training', commit_description='', oid='843c6edcf99e5912143d4c114ea39ce833059052', pr_url=None, repo_url=RepoUrl('https://huggingface.co/nikhilsoni700/dl_project_LoRA', endpoint='https://huggingface.co', repo_type='model', repo_id='nikhilsoni700/dl_project_LoRA'), pr_revision=None, pr_num=None)

# %%
from IPython.display import display, Markdown

link_to_model = f"https://huggingface.co/{repo_id}"
display(Markdown("### Your model has finished training.\nAccess it here: {}".format(link_to_model)))
# Out:
# ### Your model has finished training.
# Access it here: https://huggingface.co/nikhilsoni700/dl_project_LoRA

# %% [markdown]
# Let's generate some images with it!

# %% [markdown]
# ## Inference

# %%
import torch
from diffusers import DiffusionPipeline, AutoencoderKL

vae = AutoencoderKL.from_pretrained("madebyollin/sdxl-vae-fp16-fix", torch_dtype=torch.float16)
pipe = DiffusionPipeline.from_pretrained(
    "stabilityai/stable-diffusion-xl-base-1.0",
    vae=vae,
    torch_dtype=torch.float16,
    variant="fp16",
    use_safetensors=True
)
pipe.load_lora_weights("nikhilsoni700/dl_project_LoRA")
_ = pipe.to("cuda")
# Out:
# Fetching 17 files:   0%|          | 0/17 [00:00<?, ?it/s]
# model.fp16.safetensors:   0%|          | 0.00/246M [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/5.14G [00:00<?, ?B/s]
# model.fp16.safetensors:   0%|          | 0.00/1.39G [00:00<?, ?B/s]
# diffusion_pytorch_model.fp16.safetensors:   0%|          | 0.00/167M [00:00<?, ?B/s]
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# pytorch_lora_weights.safetensors:   0%|          | 0.00/23.4M [00:00<?, ?B/s]

# %%
prompt = "A AI avatar photo of Advik Gupta for Snapchat." # @param

# image = pipe(prompt=prompt, num_inference_steps=25).images[0]
# image

image = pipe(prompt=prompt, num_inference_steps=25, num_images_per_prompt = 3)
image_grid(image.images, 1, 3)
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=768x256>

# %% [markdown]
# We can similarly make multiple images with multiple captions!
